# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
from sklearn.preprocessing import LabelEncoder, StandardScaler
from sklearn.model_selection import train_test_split
from sklearn.linear_model import LinearRegression
from sklearn.metrics import mean_squared_error, r2_score, confusion_matrix, classification_report

# %%
data = pd.read_csv("seattle-weather.csv")

# %%
data.head()
# Out:
#          date  precipitation  temp_max  temp_min  wind  weather
# 0  2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1  2012-01-02           10.9      10.6       2.8   4.5     rain
# 2  2012-01-03            0.8      11.7       7.2   2.3     rain
# 3  2012-01-04           20.3      12.2       5.6   4.7     rain
# 4  2012-01-05            1.3       8.9       2.8   6.1     rain

# %%
sns.pairplot(data)
plt.show()

# %%
numeric_data = data.drop(columns=['date'])

# %%
numeric_data
# Out:
#       precipitation  temp_max  temp_min  wind  weather
# 0               0.0      12.8       5.0   4.7  drizzle
# 1              10.9      10.6       2.8   4.5     rain
# 2               0.8      11.7       7.2   2.3     rain
# 3              20.3      12.2       5.6   4.7     rain
# 4               1.3       8.9       2.8   6.1     rain
# ...             ...       ...       ...   ...      ...
# 1456            8.6       4.4       1.7   2.9     rain
# 1457            1.5       5.0       1.7   1.3     rain
# 1458            0.0       7.2       0.6   2.6      fog
# 1459            0.0       5.6      -1.0   3.4      sun
# 1460            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 5 columns]

# %%
label_encoder = LabelEncoder()
numeric_data['weather'] = label_encoder.fit_transform(numeric_data['weather'])

# %%
label_encoder
# Out:
# LabelEncoder()

# %%
plt.figure(figsize=(10, 8))
sns.heatmap(numeric_data.corr(), annot=True, cmap='coolwarm')
plt.show()

# %%
data = data.dropna()

# %%
data
# Out:
#             date  precipitation  temp_max  temp_min  wind  weather
# 0     2012-01-01            0.0      12.8       5.0   4.7  drizzle
# 1     2012-01-02           10.9      10.6       2.8   4.5     rain
# 2     2012-01-03            0.8      11.7       7.2   2.3     rain
# 3     2012-01-04           20.3      12.2       5.6   4.7     rain
# 4     2012-01-05            1.3       8.9       2.8   6.1     rain
# ...          ...            ...       ...       ...   ...      ...
# 1456  2015-12-27            8.6       4.4       1.7   2.9     rain
# 1457  2015-12-28            1.5       5.0       1.7   1.3     rain
# 1458  2015-12-29            0.0       7.2       0.6   2.6      fog
# 1459  2015-12-30            0.0       5.6      -1.0   3.4      sun
# 1460  2015-12-31            0.0       5.6      -2.1   3.5      sun
#
# [1461 rows x 6 columns]

# %%
data['weather'] = label_encoder.fit_transform(data['weather'])

# %%
X = data[['precipitation', 'temp_max', 'temp_min', 'wind']]
y = data['weather']

# %%
X
# Out:
#       precipitation  temp_max  temp_min  wind
# 0               0.0      12.8       5.0   4.7
# 1              10.9      10.6       2.8   4.5
# 2               0.8      11.7       7.2   2.3
# 3              20.3      12.2       5.6   4.7
# 4               1.3       8.9       2.8   6.1
# ...             ...       ...       ...   ...
# 1456            8.6       4.4       1.7   2.9
# 1457            1.5       5.0       1.7   1.3
# 1458            0.0       7.2       0.6   2.6
# 1459            0.0       5.6      -1.0   3.4
# 1460            0.0       5.6      -2.1   3.5
#
# [1461 rows x 4 columns]

# %%
y
# Out:
# 0       0
# 1       2
# 2       2
# 3       2
# 4       2
#        ..
# 1456    2
# 1457    2
# 1458    1
# 1459    4
# 1460    4
# Name: weather, Length: 1461, dtype: int64

# %%
scaler = StandardScaler()
X_scaled = scaler.fit_transform(X)

# %%
scaler
# Out:
# StandardScaler()

# %%
X_scaled
# Out:
# array([[-0.45364986, -0.49529914, -0.64421175,  1.01497975],
#        [ 1.17859791, -0.79473121, -1.08234662,  0.87583314],
#        [-0.33385186, -0.64501518, -0.20607688, -0.65477956],
#        ...,
#        [-0.45364986, -1.25748987, -1.52048149, -0.44605965],
#        [-0.45364986, -1.47525865, -1.83912504,  0.11052679],
#        [-0.45364986, -1.47525865, -2.05819247,  0.18010009]])

# %%
n_lags = 3
X_seq, y_seq = [], []

for i in range(len(X_scaled) - n_lags):
    X_seq.append(X_scaled[i:i + n_lags])
    y_seq.append(y[i + n_lags])

X_seq = np.array(X_seq)
y_seq = np.array(y_seq)

# %%
X_seq
# Out:
# array([[[-0.45364986, -0.49529914, -0.64421175,  1.01497975],
#         [ 1.17859791, -0.79473121, -1.08234662,  0.87583314],
#         [-0.33385186, -0.64501518, -0.20607688, -0.65477956]],
#
#        [[ 1.17859791, -0.79473121, -1.08234662,  0.87583314],
#         [-0.33385186, -0.64501518, -0.20607688, -0.65477956],
#         [ 2.58622442, -0.57696243, -0.52472042,  1.01497975]],
#
#        [[-0.33385186, -0.64501518, -0.20607688, -0.65477956],
#         [ 2.58622442, -0.57696243, -0.52472042,  1.01497975],
#         [-0.2589781 , -1.02611054, -1.08234662,  1.98900601]],
#
#        ...,
#
#        [[-0.45364986, -1.63858523, -1.63997282, -0.51563295],
#         [ 0.83417865, -1.63858523, -1.30141406, -0.23733973],
#         [-0.2290286 , -1.55692194, -1.30141406, -1.35051261]],
#
#        [[ 0.83417865, -1.63858523, -1.30141406, -0.23733973],
#         [-0.2290286 , -1.55692194, -1.30141406, -1.35051261],
#         [-0.45364986, -1.25748987, -1.52048149, -0.44605965]],
#
#        [[-0.2290286 , -1.55692194, -1.30141406, -1.35051261],
#         [-0.45364986, -1.25748987, -1.52048149, -0.44605965],
#         [-0.45364986, -1.47525865, -1.83912504,  0.11052679]]])

# %%
y_seq
# Out:
# array([2, 2, 2, ..., 1, 4, 4])

# %%
X_seq_flat = X_seq.reshape(X_seq.shape[0], -1)

# %%
X_seq_flat
# Out:
# array([[-0.45364986, -0.49529914, -0.64421175, ..., -0.64501518,
#         -0.20607688, -0.65477956],
#        [ 1.17859791, -0.79473121, -1.08234662, ..., -0.57696243,
#         -0.52472042,  1.01497975],
#        [-0.33385186, -0.64501518, -0.20607688, ..., -1.02611054,
#         -1.08234662,  1.98900601],
#        ...,
#        [-0.45364986, -1.63858523, -1.63997282, ..., -1.55692194,
#         -1.30141406, -1.35051261],
#        [ 0.83417865, -1.63858523, -1.30141406, ..., -1.25748987,
#         -1.52048149, -0.44605965],
#        [-0.2290286 , -1.55692194, -1.30141406, ..., -1.47525865,
#         -1.83912504,  0.11052679]])

# %%
X_train, X_test, y_train, y_test = train_test_split(X_seq_flat, y_seq, test_size=0.2, random_state=42)

# %%
lr_model = LinearRegression()
lr_model.fit(X_train, y_train)
# Out:
# LinearRegression()

# %%
y_pred = lr_model.predict(X_test)

# %%
y_pred
# Out:
# array([2.62280338, 2.77392328, 2.90625169, 2.79962543, 2.39105308,
#        2.85117971, 2.83403322, 2.07767231, 3.33777825, 3.01818941,
#        2.92845599, 3.47830366, 2.61167834, 3.59301099, 2.57278324,
#        2.25153972, 3.02127133, 2.60237401, 2.72803963, 1.71409531,
#        2.43175378, 3.29390501, 3.35871146, 2.26493863, 2.83373339,
#        2.52749072, 2.57597914, 3.86650992, 1.8043424 , 2.01985548,
#        3.30513624, 2.88708857, 2.63563957, 2.42218967, 3.00945239,
#        2.35225967, 2.65795827, 1.77423726, 2.2575497 , 3.15685766,
#        2.86403355, 2.94579796, 2.18437712, 3.41664928, 2.80016669,
#        1.84254386, 2.44099822, 2.69533015, 3.0287668 , 3.20036612,
#        2.91728548, 3.85985938, 3.05576846, 2.94699429, 2.69007453,
#        2.87830462, 2.79515938, 3.55877221, 2.29928398, 3.12649292,
#        2.44226234, 2.17244746, 3.07173621, 3.1012589 , 3.13952512,
#        2.81979868, 2.2720632 , 2.32460342, 2.74102534, 2.88659201,
#        2.28570255, 3.1361777 , 2.1174882 , 2.79071601, 2.1376235 ,
#        2.39213826, 2.91273921, 2.9865752 , 2.05435932, 2.49048584,
#        2.35137538, 2.1947668 , 2.35099242, 3.22998058, 2.89315111,
#        3.16222293, 2.97442857, 2.76284185, 2.2740364 , 2.76919296,
#        3.0138497 , 3.1585432 , 3.66348744, 1.86101247, 2.4186471 ,
#        2.57359164, 3.70906126, 2.68486825, 3.41259243, 2.43851662,
#        2.6104235 , 2.39949942, 2.3916872 , 2.16193907, 2.95393929,
#        2.48551085, 1.73417376, 1.90355899, 2.74923443, 2.73249794,
#        2.41281679, 2.63316418, 3.69559498, 2.41645256, 1.78704941,
#        1.87743535, 2.35277201, 3.29560702, 2.95407353, 2.2497972 ,
#        3.09521769, 3.3050382 , 2.35521481, 1.74680633, 2.41488665,
#        1.66132961, 2.27042908, 3.18014992, 3.59077471, 1.8814256 ,
#        2.19873611, 3.04778342, 2.56292682, 3.06092798, 3.35107635,
#        2.51670841, 3.5112085 , 2.33483834, 2.03492437, 2.229824  ,
#        3.18013269, 3.14557585, 3.2655479 , 2.7991476 , 2.58474998,
#        2.60319044, 3.01769401, 2.33497991, 3.53569527, 2.44966123,
#        2.15009119, 3.14101623, 3.5093655 , 3.51269996, 2.67436965,
#        2.15929542, 2.27864667, 3.4011576 , 2.96369954, 3.37020562,
#        3.0612887 , 2.81443648, 2.95287034, 2.06230025, 2.74846052,
#        3.03647518, 2.18489196, 2.86319507, 2.72935162, 3.44292585,
#        2.97591176, 2.89307242, 2.0929036 , 2.83739471, 2.6841917 ,
#        2.80025273, 2.91922218, 2.48541605, 3.05985355, 2.77651097,
#        2.85242721, 2.13744293, 2.84730609, 3.14574893, 2.07367361,
#        2.77955662, 2.43702411, 2.44254148, 2.4909154 , 3.47991886,
#        2.04675438, 2.73458003, 2.61989808, 2.50648543, 2.91863042,
#        3.25499376, 2.71732183, 2.53172547, 2.65671098, 2.56711989,
#        2.85895511, 3.55773963, 2.56824329, 2.36474289, 2.98183008,
#        2.42510861, 3.10008888, 3.43302877, 2.04788129, 2.54582397,
#        2.50637155, 2.63494738, 2.27544315, 2.30992535, 3.3974055 ,
#        2.8617036 , 3.37574242, 2.70102937, 2.39459474, 3.6582922 ,
#        2.4480524 , 1.99100924, 3.1506587 , 2.36915499, 2.38864204,
#        2.72006784, 3.67216511, 2.67863169, 1.5802319 , 1.90265319,
#        3.05639284, 3.07012038, 3.18449991, 3.09903593, 2.81841038,
#        2.661995  , 1.97940037, 2.08794335, 2.76976526, 2.15571698,
#        2.35080001, 2.37611571, 2.78970394, 2.33631866, 2.45299799,
#        2.7148717 , 2.36574387, 3.13133669, 2.71566018, 2.59303248,
#        2.76911018, 2.24915815, 1.93421935, 2.01334808, 2.62412305,
#        3.43308833, 2.48649537, 2.7169587 , 2.33942597, 2.46085141,
#        2.40899991, 2.17431038, 2.93128   , 3.3786642 , 2.80581606,
#        3.55226513, 3.16047894, 2.57883353, 2.18300355, 3.03434656,
#        3.05318649, 2.75186047, 3.42839358, 2.09771541, 2.6708469 ,
#        2.51534943, 2.88899377, 2.51063912, 3.11434573, 2.3713694 ,
#        3.19392756, 2.61191396, 2.59914065, 3.02142775, 2.90352036,
#        2.72446362, 2.63659636, 2.85113375, 3.00205536, 1.98492365,
#        3.02441782, 2.50273383])

# %%
y_pred_classes = np.round(y_pred).astype(int)

# %%
y_pred_classes
# Out:
# array([3, 3, 3, 3, 2, 3, 3, 2, 3, 3, 3, 3, 3, 4, 3, 2, 3, 3, 3, 2, 2, 3,
#        3, 2, 3, 3, 3, 4, 2, 2, 3, 3, 3, 2, 3, 2, 3, 2, 2, 3, 3, 3, 2, 3,
#        3, 2, 2, 3, 3, 3, 3, 4, 3, 3, 3, 3, 3, 4, 2, 3, 2, 2, 3, 3, 3, 3,
#        2, 2, 3, 3, 2, 3, 2, 3, 2, 2, 3, 3, 2, 2, 2, 2, 2, 3, 3, 3, 3, 3,
#        2, 3, 3, 3, 4, 2, 2, 3, 4, 3, 3, 2, 3, 2, 2, 2, 3, 2, 2, 2, 3, 3,
#        2, 3, 4, 2, 2, 2, 2, 3, 3, 2, 3, 3, 2, 2, 2, 2, 2, 3, 4, 2, 2, 3,
#        3, 3, 3, 3, 4, 2, 2, 2, 3, 3, 3, 3, 3, 3, 3, 2, 4, 2, 2, 3, 4, 4,
#        3, 2, 2, 3, 3, 3, 3, 3, 3, 2, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3,
#        3, 2, 3, 3, 3, 2, 3, 3, 2, 3, 2, 2, 2, 3, 2, 3, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 4, 3, 2, 3, 2, 3, 3, 2, 3, 3, 3, 2, 2, 3, 3, 3, 3, 2, 4,
#        2, 2, 3, 2, 2, 3, 4, 3, 2, 2, 3, 3, 3, 3, 3, 3, 2, 2, 3, 2, 2, 2,
#        3, 2, 2, 3, 2, 3, 3, 3, 3, 2, 2, 2, 3, 3, 2, 3, 2, 2, 2, 2, 3, 3,
#        3, 4, 3, 3, 2, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 2, 3, 3, 3, 3, 3, 3,
#        3, 3, 3, 2, 3, 3])

# %%
y_pred_classes = np.clip(y_pred_classes, 0, len(label_encoder.classes_) - 1)

# %%
mse = mean_squared_error(y_test, y_pred)
r2 = r2_score(y_test, y_pred)
print('Mean Squared Error:', mse)
print('R-squared:', r2)
# Out:
# Mean Squared Error: 1.2734771782372982
# R-squared: 0.131512684562764

# %%
print(classification_report(y_test, y_pred_classes, target_names=label_encoder.classes_))
# Out:
#               precision    recall  f1-score   support
#
#      drizzle       0.00      0.00      0.00        10
#          fog       0.00      0.00      0.00        25
#         rain       0.63      0.53      0.57       121
#         snow       0.01      0.67      0.02         3
#          sun       0.94      0.11      0.20       133
#
#     accuracy                           0.28       292
#    macro avg       0.32      0.26      0.16       292
# weighted avg       0.69      0.28      0.33       292
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))
# /usr/local/lib/python3.10/dist-packages/sklearn/metrics/_classification.py:1471: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples. Use `zero_division` parameter to control this behavior.
#   _warn_prf(average, modifier, msg_start, len(result))

# %%
conf_matrix = confusion_matrix(y_test, y_pred_classes)
plt.figure(figsize=(10, 8))
sns.heatmap(conf_matrix, annot=True, cmap='Blues', fmt='d', xticklabels=label_encoder.classes_, yticklabels=label_encoder.classes_)
plt.xlabel('Predicted')
plt.ylabel('Actual')
plt.show()

# %%
plt.figure(figsize=(12, 6))
plt.plot(y_test[:50], label='True Values')
plt.plot(y_pred_classes[:50], label='Predicted Values')
plt.legend()
plt.show()

# %%
plt.figure(figsize=(12, 6))
sns.countplot(y_pred_classes)
plt.title('Distribution of Predicted Weather Classes')
plt.xlabel('Weather Class')
plt.ylabel('Frequency')
plt.xticks(ticks=np.arange(len(label_encoder.classes_)), labels=label_encoder.classes_)
plt.show()

# %%
predictions_df = pd.DataFrame({
    'Actual': y_test,
    'Predicted': y_pred_classes
})

# %%
predictions_df
# Out:
#      Actual  Predicted
# 0         4          3
# 1         2          3
# 2         2          3
# 3         4          3
# 4         2          2
# ..      ...        ...
# 287       4          3
# 288       1          3
# 289       2          2
# 290       4          3
# 291       4          3
#
# [292 rows x 2 columns]

# %%
print(predictions_df.head(10))
# Out:
#    Actual  Predicted
# 0       4          3
# 1       2          3
# 2       2          3
# 3       4          3
# 4       2          2
# 5       4          3
# 6       0          3
# 7       2          2
# 8       4          3
# 9       4          3
